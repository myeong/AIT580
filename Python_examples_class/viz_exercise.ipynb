# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/EmployeeAttrition.csv")

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
stat = df[['Age', "DailyRate", "DistanceFromHome", "Education", 
            "WorkLifeBalance", "RelationshipSatisfaction", "TotalWorkingYears"]] # way to cut a column as a data frame

# %%
stat.head()
# Out:
#    Age  DailyRate  DistanceFromHome  Education  WorkLifeBalance  \
# 0   41       1102                 1          2                1
# 1   49        279                 8          1                3
# 2   37       1373                 2          2                3
# 3   33       1392                 3          4                3
# 4   27        591                 2          1                3
#
#    RelationshipSatisfaction  TotalWorkingYears
# 0                         1                  8
# 1                         4                 10
# 2                         2                  7
# 3                         3                  8
# 4                         4                  6

# %%
corr = stat.corr()

# %%
corr
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# WorkLifeBalance          -0.021490  -0.037848         -0.026556   0.009819
# RelationshipSatisfaction  0.053535   0.007846          0.006557  -0.009118
# TotalWorkingYears         0.680381   0.014515          0.004628   0.148280
#
#                           WorkLifeBalance  RelationshipSatisfaction  \
# Age                             -0.021490                  0.053535
# DailyRate                       -0.037848                  0.007846
# DistanceFromHome                -0.026556                  0.006557
# Education                        0.009819                 -0.009118
# ...

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
plt.figure(figsize=(10, 10))

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, cmap=cmap, vmax=.4, center=0,
            square=True, linewidths=.1)
